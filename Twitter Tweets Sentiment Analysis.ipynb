# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('E://Masai School DA//UNIT 5//Machine Learning//Assignments//Assignment 16//twitter_tweets.csv')

# %%
df
# Out:
#        2401  Borderlands  Positive  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74676  9200       Nvidia  Positive
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...                                                  ...
# 74676  Just realized that the Windows partition of my...
# 74677  Just realized that my Mac window partition is ...
# 74678  Just realized the windows partition of my Mac ...
# 74679  Just realized between the windows partition of...
# 74680  Just like the windows partition of my Mac is l...
#
# [74681 rows x 4 columns]

# %% [markdown]
# # Perform Sentimental Analysis on Twitter tweets and create a model which will be able to identify the sentiments of the tweets.

# %%
df.isnull().sum()
# Out:
# 2401                                                       0
# Borderlands                                                0
# Positive                                                   0
# im getting on borderlands and i will murder you all ,    686
# dtype: int64

# %%
df.columns = ['Code', 'Area', 'Sentiment','tweet']

# %%
df
# Out:
#        Code         Area Sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74676  9200       Nvidia  Positive
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
#
#                                                    tweet
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...                                                  ...
# 74676  Just realized that the Windows partition of my...
# 74677  Just realized that my Mac window partition is ...
# 74678  Just realized the windows partition of my Mac ...
# 74679  Just realized between the windows partition of...
# 74680  Just like the windows partition of my Mac is l...
#
# [74681 rows x 4 columns]

# %%
df=df[['Sentiment','tweet']]

# %%
df
# Out:
#       Sentiment                                              tweet
# 0      Positive  I am coming to the borders and I will kill you...
# 1      Positive  im getting on borderlands and i will kill you ...
# 2      Positive  im coming on borderlands and i will murder you...
# 3      Positive  im getting on borderlands 2 and i will murder ...
# 4      Positive  im getting into borderlands and i can murder y...
# ...         ...                                                ...
# 74676  Positive  Just realized that the Windows partition of my...
# 74677  Positive  Just realized that my Mac window partition is ...
# 74678  Positive  Just realized the windows partition of my Mac ...
# 74679  Positive  Just realized between the windows partition of...
# 74680  Positive  Just like the windows partition of my Mac is l...
#
# [74681 rows x 2 columns]

# %%
df.dtypes
# Out:
# Sentiment    object
# tweet        object
# dtype: object

# %% [markdown]
# # Removing Punctuations

# %%
import re
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")
stopwords = stopwords.words("english")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Mayan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
df['tweet'] = df['tweet'].astype(str).apply(lambda x : " ".join(i for i in x.split() if i not in stopwords))
# Out:
# C:\Users\Mayan\AppData\Local\Temp\ipykernel_7364\523776700.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tweet'] = df['tweet'].astype(str).apply(lambda x : " ".join(i for i in x.split() if i not in stopwords))

# %%
df
# Out:
#       Sentiment                                              tweet
# 0      Positive                       I coming borders I kill all,
# 1      Positive                   im getting borderlands kill all,
# 2      Positive                  im coming borderlands murder all,
# 3      Positive               im getting borderlands 2 murder all,
# 4      Positive                 im getting borderlands murder all,
# ...         ...                                                ...
# 74676  Positive  Just realized Windows partition Mac like 6 yea...
# 74677  Positive  Just realized Mac window partition 6 years beh...
# 74678  Positive  Just realized windows partition Mac 6 years be...
# 74679  Positive  Just realized windows partition Mac like 6 yea...
# 74680  Positive  Just like windows partition Mac like 6 years b...
#
# [74681 rows x 2 columns]

# %%
df.describe(include='all')
# Out:
#        Sentiment  tweet
# count      74681  74681
# unique         4  66967
# top     Negative
# freq       22542   1132

# %% [markdown]
# # Drop Duplicates

# %%
df_dup=df[df.duplicated()]
df_dup
# Out:
#       Sentiment                                              tweet
# 19     Positive  first borderlands session long time actually r...
# 25     Negative     The biggest disappointment life came year ago.
# 42      Neutral                              Check epic streamer!.
# 44      Neutral                              Check epic streamer!.
# 50      Neutral  Blaming Sight Tardiness! A little bit borderla...
# ...         ...                                                ...
# 74612  Negative                 Nvidia cancel order suspected bot.
# 74614  Negative                 Nvidia cancel order suspected bot.
# 74618  Positive  This news Nvidia 3000 series ligiet excited I’...
# 74620  Positive
# 74635  Positive                                Love EVERYTHING it.
#
# [7551 rows x 2 columns]

# %%
df_dup["Sentiment"].value_counts()
# Out:
# Positive      2546
# Negative      2115
# Neutral       1741
# Irrelevant    1149
# Name: Sentiment, dtype: int64

# %%
df.drop_duplicates(inplace=True)
# Out:
# C:\Users\Mayan\AppData\Local\Temp\ipykernel_7364\3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df['Sentiment'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking String Length

# %%
df['Tweet_Length'] = df['tweet'].str.len()
# Out:
# C:\Users\Mayan\AppData\Local\Temp\ipykernel_7364\1267015023.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tweet_Length'] = df['tweet'].str.len()

# %%
df
# Out:
#       Sentiment                                              tweet  \
# 0      Positive                       I coming borders I kill all,
# 1      Positive                   im getting borderlands kill all,
# 2      Positive                  im coming borderlands murder all,
# 3      Positive               im getting borderlands 2 murder all,
# 4      Positive                 im getting borderlands murder all,
# ...         ...                                                ...
# 74676  Positive  Just realized Windows partition Mac like 6 yea...
# 74677  Positive  Just realized Mac window partition 6 years beh...
# 74678  Positive  Just realized windows partition Mac 6 years be...
# 74679  Positive  Just realized windows partition Mac like 6 yea...
# 74680  Positive  Just like windows partition Mac like 6 years b...
#
#        Tweet_Length
# 0                28
# 1                32
# 2                33
# 3                36
# 4                34
# ...             ...
# 74676            86
# 74677            80
# 74678            86
# 74679           106
# 74680            83
#
# [67130 rows x 3 columns]

# %%
df['Tweet_Length'].plot(bins=50,kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #  Checking Distribution

# %%
df.hist(column='Tweet_Length',by='Sentiment',bins=50,figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'Irrelevant'}>,
#         <AxesSubplot:title={'center':'Negative'}>],
#        [<AxesSubplot:title={'center':'Neutral'}>,
#         <AxesSubplot:title={'center':'Positive'}>]], dtype=object)

# %% [markdown]
# # finding word length

# %%
df['word_length']=df['tweet'].apply(lambda x:len(x.split(" ")))
# Out:
# C:\Users\Mayan\AppData\Local\Temp\ipykernel_7364\1197585924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['word_length']=df['tweet'].apply(lambda x:len(x.split(" ")))

# %%
df
# Out:
#       Sentiment                                              tweet  \
# 0      Positive                       I coming borders I kill all,
# 1      Positive                   im getting borderlands kill all,
# 2      Positive                  im coming borderlands murder all,
# 3      Positive               im getting borderlands 2 murder all,
# 4      Positive                 im getting borderlands murder all,
# ...         ...                                                ...
# 74676  Positive  Just realized Windows partition Mac like 6 yea...
# 74677  Positive  Just realized Mac window partition 6 years beh...
# 74678  Positive  Just realized windows partition Mac 6 years be...
# 74679  Positive  Just realized windows partition Mac like 6 yea...
# 74680  Positive  Just like windows partition Mac like 6 years b...
#
#        Tweet_Length  word_length
# 0                28            6
# 1                32            5
# 2                33            5
# 3                36            6
# 4                34            5
# ...             ...          ...
# 74676            86           15
# 74677            80           14
# 74678            86           14
# 74679           106           19
# 74680            83           15
#
# [67130 rows x 4 columns]

# %% [markdown]
# # Text Processing

# %%
# 1. Normilization(Converting all words to lower case)

df['tweet']=df['tweet'].str.lower()
# Out:
# C:\Users\Mayan\AppData\Local\Temp\ipykernel_7364\3502383184.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tweet']=df['tweet'].str.lower()

# %%
df
# Out:
#       Sentiment                                              tweet  \
# 0      Positive                       i coming borders i kill all,
# 1      Positive                   im getting borderlands kill all,
# 2      Positive                  im coming borderlands murder all,
# 3      Positive               im getting borderlands 2 murder all,
# 4      Positive                 im getting borderlands murder all,
# ...         ...                                                ...
# 74676  Positive  just realized windows partition mac like 6 yea...
# 74677  Positive  just realized mac window partition 6 years beh...
# 74678  Positive  just realized windows partition mac 6 years be...
# 74679  Positive  just realized windows partition mac like 6 yea...
# 74680  Positive  just like windows partition mac like 6 years b...
#
#        Tweet_Length  word_length
# 0                28            6
# 1                32            5
# 2                33            5
# 3                36            6
# 4                34            5
# ...             ...          ...
# 74676            86           15
# 74677            80           14
# 74678            86           14
# 74679           106           19
# 74680            83           15
#
# [67130 rows x 4 columns]

# %%
# 2. Remove Un nessarry things(Punctuation and Special Charcter)
import re
df['tweet']=df['tweet'].apply(lambda x: re.sub('[^A-Za-z0-9\s]','',x))
# Out:
# C:\Users\Mayan\AppData\Local\Temp\ipykernel_7364\2273765572.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tweet']=df['tweet'].apply(lambda x: re.sub('[^A-Za-z0-9\s]','',x))

# %%
df
# Out:
#       Sentiment                                              tweet  \
# 0      Positive                        i coming borders i kill all
# 1      Positive                    im getting borderlands kill all
# 2      Positive                   im coming borderlands murder all
# 3      Positive                im getting borderlands 2 murder all
# 4      Positive                  im getting borderlands murder all
# ...         ...                                                ...
# 74676  Positive  just realized windows partition mac like 6 yea...
# 74677  Positive  just realized mac window partition 6 years beh...
# 74678  Positive  just realized windows partition mac 6 years be...
# 74679  Positive  just realized windows partition mac like 6 yea...
# 74680  Positive  just like windows partition mac like 6 years b...
#
#        Tweet_Length  word_length
# 0                28            6
# 1                32            5
# 2                33            5
# 3                36            6
# 4                34            5
# ...             ...          ...
# 74676            86           15
# 74677            80           14
# 74678            86           14
# 74679           106           19
# 74680            83           15
#
# [67130 rows x 4 columns]

# %% [markdown]
# # Remove Least Repeated Word

# %%
all_tweet = ' '.join(df['tweet']) #Concatenate all messages into a single string
word_counts = pd.Series(all_tweet.split()).value_counts() #Count the frequency of each word
min_count = word_counts.min() #Find the least repeated words

#Remove the least repeated words from each string
df['tweet'] = df['tweet'].apply(lambda x: ' '.join([i for i in x.split() if word_counts[i] != min_count]))
# Out:
# C:\Users\Mayan\AppData\Local\Temp\ipykernel_7364\3036019129.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tweet'] = df['tweet'].apply(lambda x: ' '.join([i for i in x.split() if word_counts[i] != min_count]))

# %% [markdown]
# # Remove Most used words

# %%
most_freq_words=pd.Series(' '.join(df['tweet']).split()).value_counts().tail(50)
df['tweet']=df['tweet'].apply(lambda x: ' '.join(i for i in x.split() if i not in most_freq_words))
# Out:
# C:\Users\Mayan\AppData\Local\Temp\ipykernel_7364\31858716.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tweet']=df['tweet'].apply(lambda x: ' '.join(i for i in x.split() if i not in most_freq_words))

# %%
df
# Out:
#       Sentiment                                              tweet  \
# 0      Positive                        i coming borders i kill all
# 1      Positive                    im getting borderlands kill all
# 2      Positive                   im coming borderlands murder all
# 3      Positive                im getting borderlands 2 murder all
# 4      Positive                  im getting borderlands murder all
# ...         ...                                                ...
# 74676  Positive  just realized windows partition mac like 6 yea...
# 74677  Positive  just realized mac window partition 6 years beh...
# 74678  Positive  just realized windows partition mac 6 years be...
# 74679  Positive  just realized windows partition mac like 6 yea...
# 74680  Positive  just like windows partition mac like 6 years b...
#
#        Tweet_Length  word_length
# 0                28            6
# 1                32            5
# 2                33            5
# 3                36            6
# 4                34            5
# ...             ...          ...
# 74676            86           15
# 74677            80           14
# 74678            86           14
# 74679           106           19
# 74680            83           15
#
# [67130 rows x 4 columns]

# %% [markdown]
# # Steeming

# %%
from nltk.stem import PorterStemmer
st=PorterStemmer()
df["tweet"]=df['tweet'].apply(lambda x: ' '.join(st.stem(word) for word in x.split()))
# Out:
# C:\Users\Mayan\AppData\Local\Temp\ipykernel_7364\282289927.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tweet"]=df['tweet'].apply(lambda x: ' '.join(st.stem(word) for word in x.split()))

# %% [markdown]
# # Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lem=WordNetLemmatizer()
df["tweet"]=df['tweet'].apply(lambda x: ' '.join(lem.lemmatize(word) for word in x.split()))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Mayan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# C:\Users\Mayan\AppData\Local\Temp\ipykernel_7364\761097401.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tweet"]=df['tweet'].apply(lambda x: ' '.join(lem.lemmatize(word) for word in x.split()))

# %%
df['Sentiment'].value_counts()
# Out:
# Negative      20427
# Positive      18285
# Neutral       16577
# Irrelevant    11841
# Name: Sentiment, dtype: int64

# %%
df['Sentiment'].replace({'Negative':0,'Positive':1,'Neutral':2,'Irrelevant':3},inplace=True)
# Out:
# C:\Users\Mayan\AppData\Local\Temp\ipykernel_7364\2470346803.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sentiment'].replace({'Negative':0,'Positive':1,'Neutral':2,'Irrelevant':3},inplace=True)

# %%
df
# Out:
#        Sentiment                                              tweet  \
# 0              1                           i come border i kill all
# 1              1                         im get borderland kill all
# 2              1                      im come borderland murder all
# 3              1                     im get borderland 2 murder all
# 4              1                       im get borderland murder all
# ...          ...                                                ...
# 74676          1  just realiz window partit mac like 6 year behi...
# 74677          1  just realiz mac window partit 6 year behind nv...
# 74678          1  just realiz window partit mac 6 year behind nv...
# 74679          1  just realiz window partit mac like 6 year behi...
# 74680          1  just like window partit mac like 6 year behind...
#
#        Tweet_Length  word_length
# 0                28            6
# 1                32            5
# 2                33            5
# 3                36            6
# 4                34            5
# ...             ...          ...
# 74676            86           15
# 74677            80           14
# 74678            86           14
# 74679           106           19
# 74680            83           15
#
# [67130 rows x 4 columns]

# %% [markdown]
# # Count Vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()

# %%
x=df['tweet']
y=df['Sentiment']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
x_train_cv=cv.fit_transform(x_train)
x_test_cv=cv.transform(x_test)

# %%
from sklearn import datasets, linear_model, metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
models = {
    "Logistics Regression" : LogisticRegression(random_state=10),
    "Random Forest" : RandomForestClassifier(random_state= 11),
    "Decision Tree" : DecisionTreeClassifier(criterion= 'gini', random_state=12)
}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for name, model in models.items():
    model.fit(x_train_cv, y_train)
    y_pred = model.predict(x_test_cv)
    print(name+ " : {:.2f}%".format(metrics.accuracy_score(y_test,y_pred)*100))
    print("\n")
    print(metrics.classification_report(y_pred, y_test))
    print("\n")
    sns.heatmap(metrics.confusion_matrix(y_pred, y_test),annot = True)
    plt.show()
# Out:
# C:\Users\Mayan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistics Regression : 79.88%
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83      5306
#            1       0.83      0.76      0.80      5016
#            2       0.76      0.82      0.79      3837
#            3       0.72      0.79      0.75      2624
#
#     accuracy                           0.80     16783
#    macro avg       0.79      0.80      0.79     16783
# weighted avg       0.80      0.80      0.80     16783
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7364\1546561113.py in <module>
#       2 import seaborn as sns
#       3 for name, model in models.items():
# ----> 4     model.fit(x_train_cv, y_train)
#       5     y_pred = model.predict(x_test_cv)
#       6     print(name+ " : {:.2f}%".format(metrics.accuracy_score(y_test,y_pred)*100))
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     448             # parallel_backend contexts set at a higher level,
#     449             # since correctness does not rely on using threads.
# --> 450             trees = Parallel(
#     451                 n_jobs=self.n_jobs,
#     452                 verbose=self.verbose,
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     183             curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
#     184
# --> 185         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     186     else:
#     187         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %% [markdown]
# # Model have higher accuracy of 79.6 and cost of FP is higher
